# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sb

# %%
data = pd.read_csv("iris-1.csv")
print(data)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
print(data[['sepal.length','sepal.width']])
# Out:
#      sepal.length  sepal.width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
print(data[data['variety']=='Setosa'])
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# ...

# %%
print(data.head())
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
print(data.loc[5:10])
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa

# %%
print(data['variety'].value_counts())
# Out:
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %%
print(data['petal.length'].value_counts())
# Out:
# petal.length
# 1.4    13
# 1.5    13
# 4.5     8
# 5.1     8
# 1.3     7
# 1.6     7
# 5.6     6
# 4.9     5
# 4.0     5
# 4.7     5
# 1.7     4
# 4.8     4
# 5.0     4
# 4.4     4
# 4.2     4
# 4.1     3
# 3.9     3
# 5.8     3
# 5.7     3
# 5.5     3
# 6.1     3
# 4.6     3
# 1.9     2
# 5.2     2
# 5.4     2
# 1.2     2
# 3.3     2
# 3.5     2
# 6.7     2
# 5.3     2
# 4.3     2
# 5.9     2
# 6.0     2
# 1.0     1
# 1.1     1
# 3.7     1
# 3.8     1
# 3.6     1
# 3.0     1
# 6.3     1
# 6.6     1
# 6.9     1
# 6.4     1
# Name: count, dtype: int64

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %% [markdown]
# #### Normal plot

# %%
plt.plot(data['petal.length'])
plt.show()

# %%
plt.plot(data['variety'])
plt.show()

# %%
plt.pl(data['sepal.width'])
plt.show()

# %% [markdown]
# #### Histogram

# %%
plt.hist(data['variety'])
plt.show()
plt.hist(data['petal.length'])
plt.show()
plt.hist(data['sepal.width'])
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
sb.scatterplot(data,x = 'sepal.length',y = 'sepal.width',hue = 'variety')
plt.show()

# %%
sb.set_style('whitegrid')
sb.scatterplot(data = data,x='petal.length',y='petal.width',hue ='variety')
plt.show()

# %% [markdown]
# ## Pair plot

# %%
sb.pairplot(data=data,hue='variety')
plt.show()

# %% [markdown]
# ## histogram & density curve

# %%
sb.FacetGrid(data = data,hue='variety').map(sb.histplot,'petal.length',kde=True).add_legend()
plt.show()

# %% [markdown]
# ## box plot

# %%
sb.boxplot(data=data,x='variety',y='sepal.length')
plt.show()

# %% [markdown]
# ## Violin Plot

# %%
sb.violinplot(data = data,x='variety',y='sepal.width')
plt.show()
